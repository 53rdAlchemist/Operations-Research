# %%
import json
from gurobipy import Model, GRB, quicksum

# Compatibility function
def compatibility (dbtype, rbtype):
    comp_matrix = {
        "A": ["A", "AB"],
        "B": ["B", "AB"],
        "AB": ["AB"],
        "O": ["A", "B", "AB", "O"]
    }
    return rbtype in comp_matrix.get(dbtype, [])

# Dataset - allows for different datasets to be used if needed
def load_data(file):
    with open(file, 'r') as file:
        data = json.load(file)
    return data

# Create a compatibility graph
def Comp_graph(data):
    edges = []
    for i, recipient1 in enumerate(data):
        for j, recipient2 in enumerate(data):
            if i != j:
                #compatibility check
                for donor1 in recipient1["Donor"]:
                    for donor2 in recipient2["Donor"]:
                        if compatibility(donor1, recipient2["Recipient"]) and \
                           compatibility(donor2, recipient1["Recipient"]):
                            edges.append((i, j))
                            break
    return edges

# Optimization model
def kpd(file):
    data = load_data(file)
    edges = Comp_graph(data)

    model = Model("KPD Matching")

    x = model.addVars(edges, vtype=GRB.BINARY, name="x")

    model.setObjective(quicksum(x[e] for e in edges), GRB.MAXIMIZE)

    # Constraints
    for i in range(len(data)):
        model.addConstr(quicksum(x[e] for e in edges if e[0] == i or e[1] == i) <= 1, name=f"node_{i}_constraint")

    model.optimize()

    if model.status == GRB.OPTIMAL:
        print("Optimal solution found!")
        for e in edges:
            if x[e].x > 0.5:
                print(f"Matching: Pair {e[0]} (Recipient: {data[e[0]]['Recipient']}) ↔ "
                      f"Pair {e[1]} (Recipient: {data[e[1]]['Recipient']})")
    else:
        print("No optimal solution found.")

        
file = "To_Be_Determined.json"  
kpd(file)
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i5-12500H, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 741 rows, 76254 columns and 152508 nonzeros
# Model fingerprint: 0xade9496f
# Variable types: 0 continuous, 76254 integer (76254 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 179.0000000
# Presolve removed 349 rows and 38127 columns
# Presolve time: 0.35s
# Presolved: 392 rows, 38127 columns, 76254 nonzeros
# Found heuristic solution: objective 179.0000000
# Variable types: 0 continuous, 38127 integer (38127 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -3.9100000e+02      1s
#        1        508  -1.8000000e+01  -2.0350000e+02      1s
#        2       1286  -1.7895039e+02  -1.7895167e+02      1s
#
# Sifting complete
#
#
# Root relaxation: cutoff, 1798 iterations, 0.07 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       179.00000  179.00000  0.00%     -    0s
#
# Explored 1 nodes (1798 simplex iterations) in 0.65 seconds (0.33 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 179 179
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.790000000000e+02, best bound 1.790000000000e+02, gap 0.0000%
# Optimal solution found!
# Matching: Pair 0 (Recipient: B) ↔ Pair 55 (Recipient: A)
# Matching: Pair 1 (Recipient: B) ↔ Pair 14 (Recipient: A)
# Matching: Pair 5 (Recipient: A) ↔ Pair 6 (Recipient: B)
# Matching: Pair 7 (Recipient: A) ↔ Pair 18 (Recipient: B)
# Matching: Pair 8 (Recipient: B) ↔ Pair 23 (Recipient: A)
# Matching: Pair 16 (Recipient: A) ↔ Pair 36 (Recipient: B)
# Matching: Pair 17 (Recipient: B) ↔ Pair 19 (Recipient: A)
# Matching: Pair 22 (Recipient: B) ↔ Pair 29 (Recipient: A)
# Matching: Pair 27 (Recipient: B) ↔ Pair 35 (Recipient: A)
# Matching: Pair 28 (Recipient: B) ↔ Pair 39 (Recipient: A)
# Matching: Pair 30 (Recipient: B) ↔ Pair 58 (Recipient: A)
# Matching: Pair 33 (Recipient: B) ↔ Pair 46 (Recipient: A)
# Matching: Pair 34 (Recipient: B) ↔ Pair 52 (Recipient: A)
# Matching: Pair 37 (Recipient: B) ↔ Pair 61 (Recipient: A)
# Matching: Pair 38 (Recipient: A) ↔ Pair 41 (Recipient: B)
# Matching: Pair 45 (Recipient: B) ↔ Pair 57 (Recipient: A)
# Matching: Pair 47 (Recipient: B) ↔ Pair 63 (Recipient: A)
# Matching: Pair 50 (Recipient: B) ↔ Pair 71 (Recipient: A)
# Matching: Pair 54 (Recipient: B) ↔ Pair 79 (Recipient: A)
# Matching: Pair 56 (Recipient: B) ↔ Pair 103 (Recipient: A)
# Matching: Pair 59 (Recipient: B) ↔ Pair 88 (Recipient: A)
# Matching: Pair 60 (Recipient: B) ↔ Pair 90 (Recipient: A)
# Matching: Pair 62 (Recipient: B) ↔ Pair 92 (Recipient: A)
# Matching: Pair 68 (Recipient: B) ↔ Pair 93 (Recipient: A)
# Matching: Pair 69 (Recipient: B) ↔ Pair 98 (Recipient: A)
# Matching: Pair 73 (Recipient: B) ↔ Pair 133 (Recipient: A)
# Matching: Pair 83 (Recipient: A) ↔ Pair 89 (Recipient: B)
# Matching: Pair 84 (Recipient: B) ↔ Pair 106 (Recipient: A)
# Matching: Pair 87 (Recipient: B) ↔ Pair 108 (Recipient: A)
# Matching: Pair 91 (Recipient: B) ↔ Pair 110 (Recipient: A)
# Matching: Pair 94 (Recipient: B) ↔ Pair 111 (Recipient: A)
# Matching: Pair 97 (Recipient: B) ↔ Pair 130 (Recipient: A)
# Matching: Pair 100 (Recipient: B) ↔ Pair 113 (Recipient: A)
# Matching: Pair 102 (Recipient: B) ↔ Pair 132 (Recipient: A)
# Matching: Pair 114 (Recipient: B) ↔ Pair 138 (Recipient: A)
# Matching: Pair 119 (Recipient: B) ↔ Pair 166 (Recipient: A)
# Matching: Pair 122 (Recipient: B) ↔ Pair 150 (Recipient: A)
# Matching: Pair 124 (Recipient: B) ↔ Pair 147 (Recipient: A)
# Matching: Pair 125 (Recipient: B) ↔ Pair 176 (Recipient: A)
# Matching: Pair 129 (Recipient: B) ↔ Pair 152 (Recipient: A)
# Matching: Pair 134 (Recipient: B) ↔ Pair 142 (Recipient: A)
# Matching: Pair 135 (Recipient: B) ↔ Pair 139 (Recipient: A)
# Matching: Pair 144 (Recipient: B) ↔ Pair 174 (Recipient: A)
# Matching: Pair 145 (Recipient: B) ↔ Pair 172 (Recipient: A)
# Matching: Pair 149 (Recipient: B) ↔ Pair 178 (Recipient: A)
# Matching: Pair 153 (Recipient: B) ↔ Pair 181 (Recipient: A)
# Matching: Pair 157 (Recipient: B) ↔ Pair 221 (Recipient: A)
# Matching: Pair 159 (Recipient: B) ↔ Pair 192 (Recipient: A)
# Matching: Pair 161 (Recipient: B) ↔ Pair 194 (Recipient: A)
# Matching: Pair 164 (Recipient: B) ↔ Pair 224 (Recipient: A)
# Matching: Pair 170 (Recipient: B) ↔ Pair 201 (Recipient: A)
# Matching: Pair 171 (Recipient: B) ↔ Pair 212 (Recipient: A)
# Matching: Pair 175 (Recipient: B) ↔ Pair 218 (Recipient: A)
# Matching: Pair 177 (Recipient: B) ↔ Pair 257 (Recipient: A)
# Matching: Pair 179 (Recipient: A) ↔ Pair 184 (Recipient: B)
# Matching: Pair 182 (Recipient: B) ↔ Pair 222 (Recipient: A)
# Matching: Pair 185 (Recipient: B) ↔ Pair 281 (Recipient: A)
# Matching: Pair 186 (Recipient: B) ↔ Pair 195 (Recipient: A)
# Matching: Pair 191 (Recipient: B) ↔ Pair 239 (Recipient: A)
# Matching: Pair 206 (Recipient: B) ↔ Pair 241 (Recipient: A)
# Matching: Pair 211 (Recipient: B) ↔ Pair 249 (Recipient: A)
# Matching: Pair 213 (Recipient: B) ↔ Pair 250 (Recipient: A)
# Matching: Pair 214 (Recipient: B) ↔ Pair 343 (Recipient: A)
# Matching: Pair 219 (Recipient: B) ↔ Pair 261 (Recipient: A)
# Matching: Pair 220 (Recipient: B) ↔ Pair 276 (Recipient: A)
# Matching: Pair 223 (Recipient: B) ↔ Pair 278 (Recipient: A)
# Matching: Pair 226 (Recipient: B) ↔ Pair 229 (Recipient: A)
# Matching: Pair 230 (Recipient: B) ↔ Pair 286 (Recipient: A)
# Matching: Pair 232 (Recipient: B) ↔ Pair 301 (Recipient: A)
# Matching: Pair 234 (Recipient: A) ↔ Pair 236 (Recipient: B)
# Matching: Pair 237 (Recipient: B) ↔ Pair 290 (Recipient: A)
# Matching: Pair 238 (Recipient: B) ↔ Pair 306 (Recipient: A)
# Matching: Pair 240 (Recipient: B) ↔ Pair 361 (Recipient: A)
# Matching: Pair 243 (Recipient: B) ↔ Pair 319 (Recipient: A)
# Matching: Pair 245 (Recipient: B) ↔ Pair 327 (Recipient: A)
# Matching: Pair 253 (Recipient: B) ↔ Pair 334 (Recipient: A)
# Matching: Pair 255 (Recipient: B) ↔ Pair 336 (Recipient: A)
# Matching: Pair 258 (Recipient: B) ↔ Pair 354 (Recipient: A)
# Matching: Pair 259 (Recipient: B) ↔ Pair 316 (Recipient: A)
# Matching: Pair 260 (Recipient: B) ↔ Pair 305 (Recipient: A)
# Matching: Pair 263 (Recipient: B) ↔ Pair 346 (Recipient: A)
# Matching: Pair 270 (Recipient: B) ↔ Pair 359 (Recipient: A)
# Matching: Pair 271 (Recipient: B) ↔ Pair 360 (Recipient: A)
# Matching: Pair 272 (Recipient: B) ↔ Pair 356 (Recipient: A)
# Matching: Pair 282 (Recipient: B) ↔ Pair 373 (Recipient: A)
# Matching: Pair 285 (Recipient: B) ↔ Pair 385 (Recipient: A)
# Matching: Pair 288 (Recipient: B) ↔ Pair 388 (Recipient: A)
# Matching: Pair 289 (Recipient: B) ↔ Pair 387 (Recipient: A)
# Matching: Pair 293 (Recipient: B) ↔ Pair 374 (Recipient: A)
# Matching: Pair 294 (Recipient: B) ↔ Pair 389 (Recipient: A)
# Matching: Pair 295 (Recipient: B) ↔ Pair 392 (Recipient: A)
# Matching: Pair 297 (Recipient: B) ↔ Pair 419 (Recipient: A)
# Matching: Pair 302 (Recipient: B) ↔ Pair 402 (Recipient: A)
# Matching: Pair 310 (Recipient: B) ↔ Pair 409 (Recipient: A)
# Matching: Pair 311 (Recipient: B) ↔ Pair 417 (Recipient: A)
# Matching: Pair 324 (Recipient: B) ↔ Pair 443 (Recipient: A)
# Matching: Pair 333 (Recipient: B) ↔ Pair 429 (Recipient: A)
# Matching: Pair 342 (Recipient: B) ↔ Pair 440 (Recipient: A)
# Matching: Pair 347 (Recipient: B) ↔ Pair 442 (Recipient: A)
# Matching: Pair 349 (Recipient: B) ↔ Pair 470 (Recipient: A)
# Matching: Pair 351 (Recipient: B) ↔ Pair 401 (Recipient: A)
# Matching: Pair 355 (Recipient: B) ↔ Pair 505 (Recipient: A)
# Matching: Pair 358 (Recipient: B) ↔ Pair 445 (Recipient: A)
# Matching: Pair 362 (Recipient: B) ↔ Pair 462 (Recipient: A)
# Matching: Pair 364 (Recipient: B) ↔ Pair 459 (Recipient: A)
# Matching: Pair 366 (Recipient: B) ↔ Pair 491 (Recipient: A)
# Matching: Pair 370 (Recipient: B) ↔ Pair 467 (Recipient: A)
# Matching: Pair 371 (Recipient: B) ↔ Pair 448 (Recipient: A)
# Matching: Pair 376 (Recipient: B) ↔ Pair 476 (Recipient: A)
# Matching: Pair 381 (Recipient: B) ↔ Pair 478 (Recipient: A)
# Matching: Pair 383 (Recipient: B) ↔ Pair 481 (Recipient: A)
# Matching: Pair 386 (Recipient: B) ↔ Pair 485 (Recipient: A)
# Matching: Pair 391 (Recipient: B) ↔ Pair 489 (Recipient: A)
# Matching: Pair 393 (Recipient: B) ↔ Pair 453 (Recipient: A)
# Matching: Pair 394 (Recipient: B) ↔ Pair 538 (Recipient: A)
# Matching: Pair 396 (Recipient: B) ↔ Pair 498 (Recipient: A)
# Matching: Pair 399 (Recipient: B) ↔ Pair 495 (Recipient: A)
# Matching: Pair 400 (Recipient: B) ↔ Pair 456 (Recipient: A)
# Matching: Pair 405 (Recipient: B) ↔ Pair 537 (Recipient: A)
# Matching: Pair 406 (Recipient: B) ↔ Pair 510 (Recipient: A)
# Matching: Pair 412 (Recipient: B) ↔ Pair 511 (Recipient: A)
# Matching: Pair 416 (Recipient: B) ↔ Pair 513 (Recipient: A)
# Matching: Pair 418 (Recipient: B) ↔ Pair 519 (Recipient: A)
# Matching: Pair 424 (Recipient: B) ↔ Pair 521 (Recipient: A)
# Matching: Pair 425 (Recipient: B) ↔ Pair 509 (Recipient: A)
# Matching: Pair 430 (Recipient: B) ↔ Pair 526 (Recipient: A)
# Matching: Pair 433 (Recipient: B) ↔ Pair 528 (Recipient: A)
# Matching: Pair 437 (Recipient: B) ↔ Pair 535 (Recipient: A)
# Matching: Pair 438 (Recipient: B) ↔ Pair 508 (Recipient: A)
# Matching: Pair 446 (Recipient: B) ↔ Pair 552 (Recipient: A)
# Matching: Pair 450 (Recipient: B) ↔ Pair 555 (Recipient: A)
# Matching: Pair 457 (Recipient: B) ↔ Pair 578 (Recipient: A)
# Matching: Pair 461 (Recipient: B) ↔ Pair 562 (Recipient: A)
# Matching: Pair 466 (Recipient: B) ↔ Pair 563 (Recipient: A)
# Matching: Pair 472 (Recipient: B) ↔ Pair 566 (Recipient: A)
# Matching: Pair 475 (Recipient: B) ↔ Pair 523 (Recipient: A)
# Matching: Pair 477 (Recipient: B) ↔ Pair 589 (Recipient: A)
# Matching: Pair 479 (Recipient: B) ↔ Pair 586 (Recipient: A)
# Matching: Pair 480 (Recipient: B) ↔ Pair 599 (Recipient: A)
# Matching: Pair 482 (Recipient: B) ↔ Pair 612 (Recipient: A)
# Matching: Pair 484 (Recipient: B) ↔ Pair 607 (Recipient: A)
# Matching: Pair 488 (Recipient: B) ↔ Pair 608 (Recipient: A)
# Matching: Pair 492 (Recipient: B) ↔ Pair 610 (Recipient: A)
# Matching: Pair 493 (Recipient: B) ↔ Pair 606 (Recipient: A)
# Matching: Pair 497 (Recipient: B) ↔ Pair 624 (Recipient: A)
# Matching: Pair 501 (Recipient: B) ↔ Pair 622 (Recipient: A)
# Matching: Pair 503 (Recipient: B) ↔ Pair 627 (Recipient: A)
# Matching: Pair 506 (Recipient: B) ↔ Pair 638 (Recipient: A)
# Matching: Pair 507 (Recipient: B) ↔ Pair 633 (Recipient: A)
# Matching: Pair 515 (Recipient: B) ↔ Pair 656 (Recipient: A)
# Matching: Pair 530 (Recipient: B) ↔ Pair 619 (Recipient: A)
# Matching: Pair 531 (Recipient: B) ↔ Pair 652 (Recipient: A)
# Matching: Pair 533 (Recipient: B) ↔ Pair 642 (Recipient: A)
# Matching: Pair 534 (Recipient: B) ↔ Pair 644 (Recipient: A)
# Matching: Pair 536 (Recipient: B) ↔ Pair 648 (Recipient: A)
# Matching: Pair 540 (Recipient: B) ↔ Pair 637 (Recipient: A)
# Matching: Pair 543 (Recipient: B) ↔ Pair 655 (Recipient: A)
# Matching: Pair 548 (Recipient: B) ↔ Pair 641 (Recipient: A)
# Matching: Pair 551 (Recipient: B) ↔ Pair 659 (Recipient: A)
# Matching: Pair 556 (Recipient: B) ↔ Pair 660 (Recipient: A)
# Matching: Pair 558 (Recipient: B) ↔ Pair 709 (Recipient: A)
# Matching: Pair 559 (Recipient: B) ↔ Pair 676 (Recipient: A)
# Matching: Pair 560 (Recipient: B) ↔ Pair 682 (Recipient: A)
# Matching: Pair 561 (Recipient: B) ↔ Pair 686 (Recipient: A)
# Matching: Pair 564 (Recipient: B) ↔ Pair 688 (Recipient: A)
# Matching: Pair 575 (Recipient: B) ↔ Pair 696 (Recipient: A)
# Matching: Pair 583 (Recipient: B) ↔ Pair 697 (Recipient: A)
# Matching: Pair 585 (Recipient: B) ↔ Pair 700 (Recipient: A)
# Matching: Pair 587 (Recipient: B) ↔ Pair 708 (Recipient: A)
# Matching: Pair 600 (Recipient: B) ↔ Pair 717 (Recipient: A)
# Matching: Pair 603 (Recipient: B) ↔ Pair 714 (Recipient: A)
# Matching: Pair 604 (Recipient: B) ↔ Pair 716 (Recipient: A)
# Matching: Pair 614 (Recipient: B) ↔ Pair 710 (Recipient: A)
# Matching: Pair 615 (Recipient: B) ↔ Pair 672 (Recipient: A)
# Matching: Pair 621 (Recipient: B) ↔ Pair 721 (Recipient: A)
# Matching: Pair 625 (Recipient: B) ↔ Pair 724 (Recipient: A)
# Matching: Pair 635 (Recipient: B) ↔ Pair 735 (Recipient: A)
# Matching: Pair 636 (Recipient: B) ↔ Pair 718 (Recipient: A)
# Matching: Pair 646 (Recipient: B) ↔ Pair 726 (Recipient: A)
